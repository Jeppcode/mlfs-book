# %%
import sys
from pathlib import Path

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
from mlfs import config
settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /Users/jesper/Documents/KTH/Skalbar_ML/mlfs-book
# HopsworksSettings initialized!

# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#333;">Training Pipeline</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Select features for the model and create a Feature View with the selected features
# 2. Create training data using the feature view
# 3. Train model
# 4. Evaluate model performance
# 5. Save model to model registry

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
import os
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, r2_score
import hopsworks
from mlfs.airquality import util
import json

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
# Check if HOPSWORKS_API_KEY env variable is set or if it is set in ~/.env
if settings.HOPSWORKS_API_KEY is not None:
    api_key = settings.HOPSWORKS_API_KEY.get_secret_value()
    os.environ['HOPSWORKS_API_KEY'] = api_key
project = hopsworks.login(engine="python")
fs = project.get_feature_store() 

secrets = hopsworks.get_secrets_api()
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# 2025-11-11 10:17:44,196 INFO: Initializing external client
# 2025-11-11 10:17:44,196 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-11 10:17:45,772 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1271996

# %%
# Retrieve feature groups
air_quality_fg = fs.get_feature_group(
    name='air_quality',
    version=1,
)
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)

# %% [markdown]
# ---
#
# ## <span style="color:#ff5f27;"> 🖍 Feature View Creation and Retrieving </span>

# %%
# Select features for training data.
selected_features = air_quality_fg.select(['pm25', 'pm25_roll3', 'country', 'city', 'street', 'date']).join(
    weather_fg.select_features(), on=['city']
)
# Out:
# 2025-11-11 10:17:48,007 INFO: Using ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant'] from feature group `weather` as features for the query. To include primary key and event time use `select_all`.

# %% [markdown]
# ### Feature Views
#
# `Feature Views` are selections of features from different **Feature Groups** that make up the input and output API (or schema) for a model. A **Feature Views** can create **Training Data** and also be used in Inference to retrieve inference data.
#
# The Feature Views allows a schema in form of a query with filters, defining a model target feature/label and additional transformation functions (declarative feature encoding).
#
# In order to create Feature View we can use `FeatureStore.get_or_create_feature_view()` method.
#
# You can specify the following parameters:
#
# - `name` - name of a feature group.
#
# - `version` - version of a feature group.
#
# - `labels`- our target variable.
#
# - `transformation_functions` - declarative feature encoding (not used here)
#
# - `query` - selected features/labels for the model

# %%
feature_view = fs.get_or_create_feature_view(
    name='air_quality_fv',
    description="weather features with air quality as the target",
    version=1,
    labels=['pm25'],
    query=selected_features,
)

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Split the training data into train/test data sets </span>
#
# We use a time-series split here, with training data before this date `start_date_test_data` and test data after this date

# %%
start_date_test_data = "2025-05-01"
# Convert string to datetime object
test_start = datetime.strptime(start_date_test_data, "%Y-%m-%d")

# %%
# Read full training data from Feature View and build lag features per station
features_df, labels_df = feature_view.training_data()

# Combine labels with features for lag computations
df_all = features_df.copy()
df_all['pm25'] = labels_df['pm25']

# Ensure datetime (tz-naive) and sort
df_all['date'] = pd.to_datetime(df_all['date'], utc=True).dt.tz_convert(None)
df_all = df_all.sort_values(['country', 'city', 'street', 'date'])

# Compute lag features per station
for k in [1, 2, 3]:
    df_all[f'pm25_lag{k}'] = (
        df_all.groupby(['country', 'city', 'street'])['pm25']
              .shift(k)
    ).astype('float32')

# Define feature sets
baseline_cols = ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'pm25_roll3']
lags_cols = baseline_cols + ['pm25_lag1', 'pm25_lag2', 'pm25_lag3']

# Train per-station: baseline vs +lags, select best, save and register
from pathlib import Path

def slugify(street: str) -> str:
    import re
    base = str(street).encode('ascii', 'ignore').decode().lower()
    base = re.sub(r'[^a-z0-9]+', '_', base)
    return base.strip('_')

mr = project.get_model_registry()
results = []
for (country_i, city_i, street_i), df_station in df_all.groupby(['country','city','street']):
    # Split by time
    train_df = df_station[df_station['date'] < test_start].copy()
    test_df = df_station[df_station['date'] >= test_start].copy()

    # Skip if not enough data
    if len(train_df) < 30 or len(test_df) < 7:
        continue

    # Prepare datasets
    def prep_xy(df, cols):
        sub = df[cols + ['pm25']].dropna()
        return sub[cols], sub['pm25']

    # Baseline
    Xtr_b, ytr_b = prep_xy(train_df, baseline_cols)
    Xte_b, yte_b = prep_xy(test_df, baseline_cols)
    mse_b = r2_b = None
    model_b = None
    pred_b = None
    if len(Xtr_b) > 0 and len(Xte_b) > 0:
        model_b = XGBRegressor()
        model_b.fit(Xtr_b, ytr_b)
        pred_b = model_b.predict(Xte_b)
        mse_b = mean_squared_error(yte_b, pred_b)
        r2_b = r2_score(yte_b, pred_b)

    # +Lags
    Xtr_l, ytr_l = prep_xy(train_df, lags_cols)
    Xte_l, yte_l = prep_xy(test_df, lags_cols)
    mse_l = r2_l = None
    model_l = None
    pred_l = None
    if len(Xtr_l) > 0 and len(Xte_l) > 0:
        model_l = XGBRegressor()
        model_l.fit(Xtr_l, ytr_l)
        pred_l = model_l.predict(Xte_l)
        mse_l = mean_squared_error(yte_l, pred_l)
        r2_l = r2_score(yte_l, pred_l)

    # Choose best by MSE (lower is better)
    best_variant = None
    best_model = None
    best_cols = None
    pred_best = None
    if mse_b is not None and (mse_l is None or mse_b <= mse_l):
        best_variant = 'baseline'
        best_model = model_b
        best_cols = baseline_cols
        pred_best = pred_b
    elif mse_l is not None:
        best_variant = '+lags'
        best_model = model_l
        best_cols = lags_cols
        pred_best = pred_l
    else:
        continue

    # Save model artifacts per station
    slug = slugify(street_i)
    model_dir = Path(f"models/air_quality_xgb_{slug}")
    model_dir.mkdir(parents=True, exist_ok=True)
    best_model.save_model(str(model_dir / "model.json"))

    # Plot hindcast on test window for this station
    try:
        images_dir = model_dir / "images"
        images_dir.mkdir(parents=True, exist_ok=True)
        if pred_best is not None and len(pred_best) > 0:
            # Align lengths safely
            test_df_sorted = test_df.sort_values('date')
            plot_len = min(len(test_df_sorted), len(pred_best))
            plot_df = test_df_sorted[['date','pm25']].iloc[-plot_len:].reset_index(drop=True).copy()
            plot_df['predicted_pm25'] = pd.Series(pred_best[-plot_len:]).reset_index(drop=True)
            file_path = str(images_dir / "pm25_hindcast.png")
            _ = util.plot_air_quality_forecast(city_i, street_i, plot_df, file_path, hindcast=True)
    except Exception as e:
        print(f"Plotting failed for {city_i} / {street_i}: {e}")

    # Register model with metrics (all native Python floats); add numeric flag for best_is_lags
    def norm_float(x, default=-1.0):
        try:
            v = float(x)
            if v != v:  # NaN check
                return default
            return v
        except (TypeError, ValueError):
            return default
    metrics = {
        "MSE_baseline": norm_float(mse_b),
        "R2_baseline": norm_float(r2_b),
        "MSE_lags": norm_float(mse_l),
        "R2_lags": norm_float(r2_l),
        "MSE_delta": norm_float((mse_b - mse_l) if (mse_b is not None and mse_l is not None) else None),
        "R2_delta": norm_float((r2_l - r2_b) if (r2_b is not None and r2_l is not None) else None),
        "best_is_lags": 1.0 if best_variant == '+lags' else 0.0,
    }
    model_name = f"air_quality_xgb_{slug}"
    mdl = mr.python.create_model(
        name=model_name,
        metrics=metrics,
        feature_view=feature_view,
        description=f"PM2.5 predictor for {city_i} / {street_i} ({best_variant})",
    )
    mdl.save(str(model_dir))

    # Feature importance plot for best model
    try:
        importances = getattr(best_model, 'feature_importances_', None)
        if importances is not None:
            fi_df = pd.DataFrame({'feature': best_cols, 'importance': importances}).sort_values('importance', ascending=False)
            fi_path = images_dir / 'feature_importance.png'
            plt.figure(figsize=(7, 5))
            plt.barh(fi_df['feature'], fi_df['importance'])
            plt.gca().invert_yaxis()
            plt.title(f"Feature importance: {city_i} / {street_i}")
            plt.tight_layout()
            plt.savefig(str(fi_path))
            plt.close()
    except Exception as e:
        print(f"Feature importance plotting failed for {city_i} / {street_i}: {e}")

    # Measure improvement/regression (positive means +lags improved MSE)
    mse_delta = None
    r2_delta = None
    if mse_b is not None and mse_l is not None:
        mse_delta = mse_b - mse_l
    if r2_b is not None and r2_l is not None:
        r2_delta = (r2_l - r2_b)

    results.append({
        'country': country_i,
        'city': city_i,
        'street': street_i,
        'best_variant': best_variant,
        'mse_baseline': mse_b,
        'mse_lags': mse_l,
        'mse_delta': mse_delta,
        'r2_baseline': r2_b,
        'r2_lags': r2_l,
        'r2_delta': r2_delta,
        'model_name': model_name,
        'model_dir': str(model_dir),
    })

summary_df = pd.DataFrame(results)
summary_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.98s)
# 2025-11-11 10:29:53,692 INFO: Provenance cached data - overwriting last accessed/created training dataset from 7 to 8.
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading /Users/jesper/Documents/KTH/Skalbar_ML/mlfs-book/notebooks/airquality/models/air_quality_xgb_storvge…
# Uploading /Users/jesper/Documents/KTH/Skalbar_ML/mlfs-book/notebooks/airquality/models/air_quality_xgb_storvge…
# Uploading /Users/jesper/Documents/KTH/Skalbar_ML/mlfs-book/notebooks/airquality/model_schema.json: 0.000%|    …
# Model created, explore it at https://c.app.hopsworks.ai:443/p/1271996/models/air_quality_xgb_storvgen_ljugarn_sweden/2
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading /Users/jesper/Documents/KTH/Skalbar_ML/mlfs-book/notebooks/airquality/models/air_quality_xgb_stra_tv…
# Uploading /Users/jesper/Documents/KTH/Skalbar_ML/mlfs-book/notebooks/airquality/models/air_quality_xgb_stra_tv…
# ...

# %%
# Summary of per-station results
from IPython.display import display
try:
    display(summary_df.head(10))
except NameError:
    print("No results computed.")
# Out:
#   country     city                             street best_variant  \
# 0  sweden  gotland         Storvägen, Ljugarn, Sweden        +lags
# 1  sweden  gotland     Östra Tvärgatan, Visby, Sweden        +lags
# 2  sweden   kalmar  Norra Långgatan, Borgholm, Sweden        +lags
#
#    mse_baseline   mse_lags  mse_delta  r2_baseline   r2_lags  r2_delta  \
# 0      9.872634   6.743608   3.129026     0.089765  0.378254  0.288489
# 1     16.306149  14.526815   1.779333     0.276205  0.355186  0.078981
# 2      3.356619   2.367488   0.989131    -0.842114 -0.299278  0.542835
#
#                                        model_name  \
# 0         air_quality_xgb_storvgen_ljugarn_sweden
# 1      air_quality_xgb_stra_tvrgatan_visby_sweden
# 2  air_quality_xgb_norra_lnggatan_borgholm_sweden
#
#                                            model_dir
# 0     models/air_quality_xgb_storvgen_ljugarn_sweden
# 1  models/air_quality_xgb_stra_tvrgatan_visby_sweden
# ...

# %% [markdown]
# The `Feature View` is now saved in Hopsworks and you can retrieve it using `FeatureStore.get_feature_view(name='...', version=1)`.

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#ff5f27;">🧬 Modeling</span>
#
# We will train a regression model to predict pm25 using our 4 features (wind_speed, wind_dir, temp, precipitation)

# %%
# (metrics are computed per-station in the loop; show summary)
from IPython.display import display
try:
    display(summary_df[['city','street','best_variant','mse_baseline','mse_lags','mse_delta','r2_baseline','r2_lags','r2_delta','model_dir']])
except NameError:
    print("No results computed.")
# Out:
#       city                             street best_variant  mse_baseline  \
# 0  gotland         Storvägen, Ljugarn, Sweden        +lags      9.872634
# 1  gotland     Östra Tvärgatan, Visby, Sweden        +lags     16.306149
# 2   kalmar  Norra Långgatan, Borgholm, Sweden        +lags      3.356619
#
#     mse_lags  mse_delta  r2_baseline   r2_lags  r2_delta  \
# 0   6.743608   3.129026     0.089765  0.378254  0.288489
# 1  14.526815   1.779333     0.276205  0.355186  0.078981
# 2   2.367488   0.989131    -0.842114 -0.299278  0.542835
#
#                                            model_dir
# 0     models/air_quality_xgb_storvgen_ljugarn_sweden
# 1  models/air_quality_xgb_stra_tvrgatan_visby_sweden
# 2  models/air_quality_xgb_norra_lnggatan_borgholm...

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'>🗄 Model Registry</span>
#
# One of the features in Hopsworks is the model registry. This is where you can store different versions of models and compare their performance. Models from the registry can then be served as API endpoints.

# %%
# (models saved and registered per-station in the training loop)

# %%
# (metrics prepared per-station in the training loop)

# %%
# (models are registered per-station in the training loop; see `summary_df`)

# %% [markdown]
# ---
# ## <span style="color:#ff5f27;">⏭️ **Next:** Part 04: Batch Inference</span>
#
# In the following notebook you will use your model for Batch Inference.
